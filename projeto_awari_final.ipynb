# %% [markdown]
# <a href="https://colab.research.google.com/github/lbarbozano/projeto_final_awari/blob/main/projeto_awari_final.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#biblioteca de conexão ao banco de dados, analise, manipulação
# !pip install pymysql


import pymysql.cursors
import numpy as np 
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# Out:
# ...
#      |████████████████████████████████| 51kB 2.7MB/s
# ...

# %%
#host onde está o banco
#user usuário
#password senha de acesso ao db4free

cbd = pymysql.connect(host='db4free.net',
                      user='rodrigosantos',
                      password='78451225',
                      db='dbrodrigosantos3',
                      charset='utf8mb4',
                      cursorclass=pymysql.cursors.DictCursor)

cursor = cbd.cursor()

# %%
comando_sql = "SELECT *FROM atividadecaio"
cursor.execute(comando_sql)

#retorna todos os dados da tabela

dados = cursor.fetchall()
cbd.close()
print(type(dados))
# Out:
# <class 'list'>

# %%
print(dados)
# Out:
# [{'id': 458, 'temperatura': 23.7, 'umidade': 63.0, 'horario': datetime.datetime(2020, 8, 27, 23, 31, 39)}, {'id': 459, 'temperatura': 23.7, 'umidade': 65.0, 'horario': datetime.datetime(2020, 8, 27, 23, 31, 47)}, {'id': 460, 'temperatura': 23.7, 'umidade': 64.0, 'horario': datetime.datetime(2020, 8, 27, 23, 31, 56)}, {'id': 461, 'temperatura': 23.7, 'umidade': 64.0, 'horario': datetime.datetime(2020, 8, 27, 23, 32, 7)}, {'id': 462, 'temperatura': 23.7, 'umidade': 65.0, 'horario': datetime.datetime(2020, 8, 27, 23, 32, 16)}, {'id': 463, 'temperatura': 23.8, 'umidade': 64.0, 'horario': datetime.datetime(2020, 8, 27, 23, 32, 24)}, {'id': 464, 'temperatura': 23.7, 'umidade': 65.0, 'horario': datetime.datetime(2020, 8, 27, 23, 32, 33)}, {'id': 465, 'temperatura': 23.7, 'umidade': 64.0, 'horario': datetime.datetime(2020, 8, 27, 23, 33, 10)}, {'id': 466, 'temperatura': 23.7, 'umidade': 64.0, 'horario': datetime.datetime(2020, 8, 27, 23, 33, 19)}, {'id': 467, 'temperatura': 23.8, 'umidade': 
# ...

# %%
for l in dados:
  print(l)
# Out:
# {'id': 458, 'temperatura': 23.7, 'umidade': 63.0, 'horario': datetime.datetime(2020, 8, 27, 23, 31, 39)}
# {'id': 459, 'temperatura': 23.7, 'umidade': 65.0, 'horario': datetime.datetime(2020, 8, 27, 23, 31, 47)}
# {'id': 460, 'temperatura': 23.7, 'umidade': 64.0, 'horario': datetime.datetime(2020, 8, 27, 23, 31, 56)}
# {'id': 461, 'temperatura': 23.7, 'umidade': 64.0, 'horario': datetime.datetime(2020, 8, 27, 23, 32, 7)}
# {'id': 462, 'temperatura': 23.7, 'umidade': 65.0, 'horario': datetime.datetime(2020, 8, 27, 23, 32, 16)}
# {'id': 463, 'temperatura': 23.8, 'umidade': 64.0, 'horario': datetime.datetime(2020, 8, 27, 23, 32, 24)}
# {'id': 464, 'temperatura': 23.7, 'umidade': 65.0, 'horario': datetime.datetime(2020, 8, 27, 23, 32, 33)}
# {'id': 465, 'temperatura': 23.7, 'umidade': 64.0, 'horario': datetime.datetime(2020, 8, 27, 23, 33, 10)}
# {'id': 466, 'temperatura': 23.7, 'umidade': 64.0, 'horario': datetime.datetime(2020, 8, 27, 23, 33, 19)}
# ...

# %%
dados[0]
# Out:
# {'horario': datetime.datetime(2020, 8, 27, 23, 31, 39),
#  'id': 458,
#  'temperatura': 23.7,
#  'umidade': 63.0}

# %%
tabela1 = pd.DataFrame(dados)
print(type(tabela1))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
tabela1.head()
# Out:
#     id  temperatura  umidade             horario
# 0  458         23.7     63.0 2020-08-27 23:31:39
# 1  459         23.7     65.0 2020-08-27 23:31:47
# 2  460         23.7     64.0 2020-08-27 23:31:56
# 3  461         23.7     64.0 2020-08-27 23:32:07
# 4  462         23.7     65.0 2020-08-27 23:32:16

# %%
#mais usado para uma unica informação na tabela

serie1 = pd.Series(dados)

# %%
print(serie1)
# Out:
# 0       {'id': 458, 'temperatura': 23.7, 'umidade': 63...
# 1       {'id': 459, 'temperatura': 23.7, 'umidade': 65...
# 2       {'id': 460, 'temperatura': 23.7, 'umidade': 64...
# 3       {'id': 461, 'temperatura': 23.7, 'umidade': 64...
# 4       {'id': 462, 'temperatura': 23.7, 'umidade': 65...
#                               ...
# 3847    {'id': 4309, 'temperatura': 20.5, 'umidade': 9...
# 3848    {'id': 4310, 'temperatura': 20.3, 'umidade': 9...
# 3849    {'id': 4311, 'temperatura': 20.2, 'umidade': 9...
# 3850    {'id': 4312, 'temperatura': 20.2, 'umidade': 9...
# 3851    {'id': 4313, 'temperatura': 20.2, 'umidade': 9...
# Length: 3852, dtype: object

# %%
#20 primeiros dados

serie1.head(20)
# Out:
# 0     {'id': 458, 'temperatura': 23.7, 'umidade': 63...
# 1     {'id': 459, 'temperatura': 23.7, 'umidade': 65...
# 2     {'id': 460, 'temperatura': 23.7, 'umidade': 64...
# 3     {'id': 461, 'temperatura': 23.7, 'umidade': 64...
# 4     {'id': 462, 'temperatura': 23.7, 'umidade': 65...
# 5     {'id': 463, 'temperatura': 23.8, 'umidade': 64...
# 6     {'id': 464, 'temperatura': 23.7, 'umidade': 65...
# 7     {'id': 465, 'temperatura': 23.7, 'umidade': 64...
# 8     {'id': 466, 'temperatura': 23.7, 'umidade': 64...
# 9     {'id': 467, 'temperatura': 23.8, 'umidade': 64...
# 10    {'id': 468, 'temperatura': 23.8, 'umidade': 64...
# 11    {'id': 469, 'temperatura': 23.8, 'umidade': 63...
# 12    {'id': 470, 'temperatura': 23.8, 'umidade': 63...
# 13    {'id': 471, 'temperatura': 23.7, 'umidade': 64...
# 14    {'id': 472, 'temperatura': 23.7, 'umidade': 64...
# 15    {'id': 473, 'temperatura': 23.7, 'umidade': 64...
# 16    {'id': 474, 'temperatura': 23.7, 'umidade': 64...
# ...

# %%
#20 ultimos dados

serie1.tail(20)
# Out:
# 3832    {'id': 4294, 'temperatura': 20.3, 'umidade': 9...
# 3833    {'id': 4295, 'temperatura': 20.1, 'umidade': 9...
# 3834    {'id': 4296, 'temperatura': 20.1, 'umidade': 9...
# 3835    {'id': 4297, 'temperatura': 20.2, 'umidade': 9...
# 3836    {'id': 4298, 'temperatura': 19.9, 'umidade': 9...
# 3837    {'id': 4299, 'temperatura': 20.1, 'umidade': 9...
# 3838    {'id': 4300, 'temperatura': 19.8, 'umidade': 9...
# 3839    {'id': 4301, 'temperatura': 20.4, 'umidade': 9...
# 3840    {'id': 4302, 'temperatura': 20.2, 'umidade': 9...
# 3841    {'id': 4303, 'temperatura': 19.9, 'umidade': 9...
# 3842    {'id': 4304, 'temperatura': 19.9, 'umidade': 9...
# 3843    {'id': 4305, 'temperatura': 19.9, 'umidade': 9...
# 3844    {'id': 4306, 'temperatura': 20.1, 'umidade': 9...
# 3845    {'id': 4307, 'temperatura': 19.9, 'umidade': 9...
# 3846    {'id': 4308, 'temperatura': 20.3, 'umidade': 9...
# 3847    {'id': 4309, 'temperatura': 20.5, 'umidade': 9...
# ...

# %%
#informa como está a organização dos dados

serie1.index
# Out:
# RangeIndex(start=0, stop=3852, step=1)

# %%
#10 primeiros dados da temperatura

tabela1['temperatura'].head(10)
# Out:
# 0    23.7
# 1    23.7
# 2    23.7
# 3    23.7
# 4    23.7
# 5    23.8
# 6    23.7
# 7    23.7
# 8    23.7
# 9    23.8
# Name: temperatura, dtype: float64

# %%
#10 ultimos dados da temperatura

tabela1['temperatura'].tail(10)
# Out:
# 3842    19.9
# 3843    19.9
# 3844    20.1
# 3845    19.9
# 3846    20.3
# 3847    20.5
# 3848    20.3
# 3849    20.2
# 3850    20.2
# 3851    20.2
# Name: temperatura, dtype: float64

# %%
#menor temperatura

tabela1['temperatura'].min()
# Out:
# 18.8

# %%
#maior temperatura

tabela1['temperatura'].max()
# Out:
# 33.6

# %%
#media das temperaturas

tabela1['temperatura'].mean()
# Out:
# 24.885098650052015

# %%
#soma das temperaturas

tabela1['temperatura'].sum()
# Out:
# 95857.4

# %%
#informações diversas sobre a coluna temperatura

tabela1['temperatura'].describe()
# Out:
# count    3852.000000
# mean       24.885099
# std         3.651375
# min        18.800000
# 25%        22.000000
# 50%        24.800000
# 75%        26.900000
# max        33.600000
# Name: temperatura, dtype: float64

# %%
tabela1['temperatura'].plot(kind='line')

# %%
sns.distplot(tabela1['temperatura'])
sns.distplot(tabela1['temperatura'], kde=False)
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.6/dist-packages/seaborn/distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.countplot(x='temperatura', data=tabela1)

# %%
sns.pairplot(tabela1, kind='reg', hue='umidade')
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/distributions.py:305: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.6/dist-packages/seaborn/distributions.py:305: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)

# %%
sns.pairplot(tabela1, hue='umidade')
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/distributions.py:305: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.6/dist-packages/seaborn/distributions.py:305: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)

# %%
#função coeficientes de correlação de todas as variáveis

tabela1.corr()
# Out:
#                    id  temperatura   umidade
# id           1.000000    -0.069544  0.416908
# temperatura -0.069544     1.000000 -0.882535
# umidade      0.416908    -0.882535  1.000000

# %%
sns.heatmap(tabela1.corr(), annot=True, center=0, cmap="YlGnBu")

# %%
tabela1.boxplot('temperatura')

# %%
sns.boxplot(x=tabela1['temperatura'])

# %%
sns.boxplot(x='umidade', y='temperatura', data=tabela1)

# %%
sns.jointplot(x='umidade', y='temperatura', data=tabela1)

# %%
#tabela da umidade

tabela1['umidade']
# Out:
# 0       63.0
# 1       65.0
# 2       64.0
# 3       64.0
# 4       65.0
#         ...
# 3847    90.0
# 3848    90.0
# 3849    90.0
# 3850    90.0
# 3851    90.0
# Name: umidade, Length: 3852, dtype: float64

# %%
#10 primeiros dados da umidade

tabela1['umidade'].head(10)
# Out:
# 0    63.0
# 1    65.0
# 2    64.0
# 3    64.0
# 4    65.0
# 5    64.0
# 6    65.0
# 7    64.0
# 8    64.0
# 9    64.0
# Name: umidade, dtype: float64

# %%
#10 ultimas dados da umidade

tabela1['umidade'].tail(10)
# Out:
# 3842    90.0
# 3843    90.0
# 3844    90.0
# 3845    90.0
# 3846    90.0
# 3847    90.0
# 3848    90.0
# 3849    90.0
# 3850    90.0
# 3851    90.0
# Name: umidade, dtype: float64

# %%
#menor umidade

tabela1['umidade'].min()
# Out:
# 44.0

# %%
#maior umidade

tabela1['umidade'].max()
# Out:
# 93.0

# %%
#media das umidades

tabela1['umidade'].mean()
# Out:
# 66.37227414330218

# %%
#soma das umidades

tabela1['umidade'].sum()
# Out:
# 255666.0

# %%
#informações diversas sobre a coluna umidade

tabela1['umidade'].describe()
# Out:
# count    3852.000000
# mean       66.372274
# std        14.713715
# min        44.000000
# 25%        59.000000
# 50%        63.000000
# 75%        85.000000
# max        93.000000
# Name: umidade, dtype: float64

# %%
tabela1['umidade'].plot(kind='line')

# %%
sns.distplot(tabela1['umidade'])
sns.distplot(tabela1['umidade'], kde=False)
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.6/dist-packages/seaborn/distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.countplot(x='umidade', data=tabela1)

# %%
tabela1.boxplot('umidade')

# %%
sns.boxplot(x=tabela1['umidade'])

# %%
#nome de cada coluna

tabela1.columns
# Out:
# Index(['id', 'temperatura', 'umidade', 'horario'], dtype='object')

# %%
#soma da tabela 1

tabela1.sum()
# Out:
# id             9186258.0
# temperatura      95857.4
# umidade         255666.0
# dtype: float64

# %%
#valor mínimo da tabela 1

tabela1.min()
# Out:
# id                             458
# temperatura                   18.8
# umidade                         44
# horario        2020-08-27 23:31:39
# dtype: object

# %%
#valor máximo da tabela 1

tabela1.max()
# Out:
# id                            4313
# temperatura                   33.6
# umidade                         93
# horario        2020-11-19 22:33:57
# dtype: object

# %%
#valor média da tabela 1

tabela1.mean()
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:3: FutureWarning: DataFrame.mean and DataFrame.median with numeric_only=None will include datetime64 and datetime64tz columns in a future version.
#   This is separate from the ipykernel package so we can avoid doing imports until
# id             2384.802181
# temperatura      24.885099
# umidade          66.372274
# dtype: float64

# %%
tabela1.median()
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:1: FutureWarning: DataFrame.mean and DataFrame.median with numeric_only=None will include datetime64 and datetime64tz columns in a future version.
#   """Entry point for launching an IPython kernel.
# id             2383.5
# temperatura      24.8
# umidade          63.0
# dtype: float64

# %%
#informações diversas sobre as colunas

tabela1.describe()
# Out:
#                 id  temperatura      umidade
# count  3852.000000  3852.000000  3852.000000
# mean   2384.802181    24.885099    66.372274
# std    1113.642877     3.651375    14.713715
# min     458.000000    18.800000    44.000000
# 25%    1420.750000    22.000000    59.000000
# 50%    2383.500000    24.800000    63.000000
# 75%    3350.250000    26.900000    85.000000
# max    4313.000000    33.600000    93.000000

# %%
#temperaturas de 29 graus pra cima

dados_filtrados = tabela1[tabela1['temperatura']>29.0]

# %%
print(dados_filtrados)
# Out:
#         id  temperatura  umidade             horario
# 1880  2338         30.1     46.0 2020-09-14 21:21:34
# 1881  2339         30.1     46.0 2020-09-14 21:21:42
# 1882  2340         30.2     46.0 2020-09-14 21:21:51
# 1883  2341         30.1     46.0 2020-09-14 21:22:00
# 1884  2342         30.1     46.0 2020-09-14 21:22:08
# ...    ...          ...      ...                 ...
# 3260  3722         33.4     50.0 2020-10-07 22:07:02
# 3261  3723         33.3     51.0 2020-10-07 22:07:11
# 3262  3724         33.4     51.0 2020-10-07 22:07:20
# 3263  3725         33.3     51.0 2020-10-07 22:07:28
# 3264  3726         33.4     50.0 2020-10-07 22:07:43
#
# [628 rows x 4 columns]

# %%
#10 primeiros dados filtrados

dados_filtrados.head(10)
# Out:
#         id  temperatura  umidade             horario
# 1880  2338         30.1     46.0 2020-09-14 21:21:34
# 1881  2339         30.1     46.0 2020-09-14 21:21:42
# 1882  2340         30.2     46.0 2020-09-14 21:21:51
# 1883  2341         30.1     46.0 2020-09-14 21:22:00
# 1884  2342         30.1     46.0 2020-09-14 21:22:08
# 1885  2343         30.1     45.0 2020-09-14 21:22:17
# 1886  2344         30.1     46.0 2020-09-14 21:22:26
# 1887  2345         30.1     45.0 2020-09-14 21:22:34
# 1888  2346         30.1     46.0 2020-09-14 21:22:43
# 1889  2347         30.1     46.0 2020-09-14 21:22:51

# %%
#10 ultimos dados filtrados

dados_filtrados.tail(10)
# Out:
#         id  temperatura  umidade             horario
# 3255  3717         33.3     51.0 2020-10-07 22:06:17
# 3256  3718         33.3     51.0 2020-10-07 22:06:26
# 3257  3719         33.5     51.0 2020-10-07 22:06:35
# 3258  3720         33.4     51.0 2020-10-07 22:06:43
# 3259  3721         33.4     50.0 2020-10-07 22:06:52
# 3260  3722         33.4     50.0 2020-10-07 22:07:02
# 3261  3723         33.3     51.0 2020-10-07 22:07:11
# 3262  3724         33.4     51.0 2020-10-07 22:07:20
# 3263  3725         33.3     51.0 2020-10-07 22:07:28
# 3264  3726         33.4     50.0 2020-10-07 22:07:43

# %%
#informações diversas sobre dados filtrados

dados_filtrados.describe()
# Out:
#                 id  temperatura     umidade
# count   628.000000   628.000000  628.000000
# mean   2916.250000    30.885510   47.218153
# std     522.184217     1.803566    3.134190
# min    2338.000000    29.100000   44.000000
# 25%    2494.750000    29.400000   45.000000
# 50%    2651.500000    29.900000   45.000000
# 75%    3569.250000    33.300000   51.000000
# max    3726.000000    33.600000   53.000000

# %%
#0, primeira linha, 1, segunda coluna
#seleciona linha e coluna

print(dados_filtrados.iloc[0,1])
# Out:
# 30.1

# %%
#0, primeira linha, 2, segunda coluna
#seleciona linha e coluna

print(dados_filtrados.iloc[0,2])
# Out:
# 46.0

# %%
# tipo de dado de cada columa

dados_filtrados.dtypes
# Out:
# id                      int64
# temperatura           float64
# umidade               float64
# horario        datetime64[ns]
# dtype: object

# %%
#Quantas temperaturas diferentes existem

len(dados_filtrados['temperatura'].unique())
# Out:
# 19

# %%
#Quantas umidades diferentes existem

len(dados_filtrados['umidade'].unique())
# Out:
# 8

# %%
#temperatura mais frequente

dados_filtrados['temperatura'].value_counts().head(1)
# Out:
# 33.3    86
# Name: temperatura, dtype: int64

# %%
#umidade mais frequente

dados_filtrados['umidade'].value_counts().head(1)
# Out:
# 45.0    282
# Name: umidade, dtype: int64

# %%
dados_filtrados['umidade'].plot(kind='line')

# %%
dados_filtrados['temperatura'].plot(kind='line')

# %%
dados_filtrados['temperatura'].plot(figsize=(12,5))

# %%
sns.distplot(dados_filtrados['umidade'])
sns.distplot(dados_filtrados['umidade'], kde=False)
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.6/dist-packages/seaborn/distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.distplot(dados_filtrados['temperatura'])
sns.distplot(dados_filtrados['temperatura'], kde=False)
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.6/dist-packages/seaborn/distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.countplot(x='umidade', data=dados_filtrados)

# %%
sns.countplot(x='temperatura', data=dados_filtrados)

# %%
sns.set_style('darkgrid')
sns.countplot(x='temperatura', data=dados_filtrados)

# %%
sns.set_style('darkgrid')
sns.countplot(x='umidade', data=dados_filtrados)

# %%
sns.set_style('whitegrid')
sns.set_context('poster')
sns.countplot(x='temperatura', data=dados_filtrados)

# %%
sns.set_style('whitegrid')
sns.set_context('poster')
sns.countplot(x='umidade', data=dados_filtrados)

# %%
sns.barplot(x='umidade', y='temperatura', data=dados_filtrados)

# %%
dados_filtrados.corr()
# Out:
#                    id  temperatura   umidade
# id           1.000000     0.941570  0.964934
# temperatura  0.941570     1.000000  0.956501
# umidade      0.964934     0.956501  1.000000

# %%
sns.heatmap(dados_filtrados.corr(), annot=True, center=0, cmap="YlGnBu")

# %%
sns.heatmap(dados_filtrados.corr())

# %%
dados_filtrados.boxplot('temperatura')

# %%
dados_filtrados.boxplot('umidade')

# %%
sns.boxplot(x=dados_filtrados['temperatura'])

# %%
sns.boxplot(x=dados_filtrados['umidade'])

# %%
sns.pairplot(dados_filtrados, kind='reg', hue='temperatura')
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/distributions.py:305: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.6/dist-packages/seaborn/distributions.py:305: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.6/dist-packages/seaborn/distributions.py:305: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.6/dist-packages/seaborn/distributions.py:305: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)

# %%
sns.pairplot(dados_filtrados, kind='reg', hue='umidade')
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/distributions.py:305: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.6/dist-packages/seaborn/distributions.py:305: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)

# %%
sns.pairplot(dados_filtrados, hue='temperatura')
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/distributions.py:305: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.6/dist-packages/seaborn/distributions.py:305: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.6/dist-packages/seaborn/distributions.py:305: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.6/dist-packages/seaborn/distributions.py:305: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)

# %%
sns.pairplot(dados_filtrados, hue='umidade')
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/distributions.py:305: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.6/dist-packages/seaborn/distributions.py:305: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)

# %%
sns.boxplot(x='umidade', y='temperatura', data=dados_filtrados)

# %%
sns.jointplot(x='umidade', y='temperatura', data=dados_filtrados)

# %%
#biblioteca warnings limpa
#biblioteca statsmodels que faz previsão em estatistica

import warnings
import statsmodels.api as sm
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
from statsmodels.tsa.stattools import adfuller

# %%
def teste (dataset):
  dados_filtrados_teste = adfuller(dataset,autolag = 'AIC')
  print('1. ADF :',dados_filtrados_teste[0])
  print('2. P.Value :',dados_filtrados_teste[1])
  print('3. Num of Lags :',dados_filtrados_teste[2])
  print('4. Num of observations used for ADF regression and cristical values calculation :',dados_filtrados_teste[3])
  print('5. Cristical values:')
  for l, val in dados_filtrados_teste[4].items():
    print("\t",l, ": ", val)

# %%
teste(dados_filtrados['temperatura'])
# Out:
# 1. ADF : -0.8367708788287719
# 2. P.Value : 0.8080816204932821
# 3. Num of Lags : 0
# 4. Num of observations used for ADF regression and cristical values calculation : 627
# 5. Cristical values:
# 	 1% :  -3.440822526288827
# 	 5% :  -2.8661606613087542
# 	 10% :  -2.5692307337540603

# %%
# !pip install pmdarima

from pmdarima import auto_arima
import warnings
warnings.filterwarnings('ignore')

# %%
stepwise_fit = auto_arima(dados_filtrados['temperatura'], trace=True, suppress_warnings=True)

stepwise_fit.summary()
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(2,1,2)(0,0,0)[0] intercept   : AIC=-409.690, Time=1.00 sec
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : AIC=-415.842, Time=0.18 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : AIC=-415.468, Time=0.11 sec
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : AIC=-415.525, Time=0.63 sec
#  ARIMA(0,1,0)(0,0,0)[0]             : AIC=-417.263, Time=0.09 sec
#  ARIMA(1,1,1)(0,0,0)[0] intercept   : AIC=-413.710, Time=0.16 sec
#
# Best model:  ARIMA(0,1,0)(0,0,0)[0]
# Total fit time: 2.193 seconds
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                            Statespace Model Results
# ...
# Dep. Variable:                      y   No. Observations:                  628
# Model:               SARIMAX(0, 1, 0)   Log Likelihood                 209.631
# Date:                Wed, 25 Nov 2020   AIC                           -417.263
# Time:                        19:47:42   BIC                           -412.822
# ...

# %%
from statsmodels.tsa.arima_model import ARIMA

# %%
print(dados_filtrados.shape)
train=dados_filtrados.iloc[:-30]
teste=dados_filtrados.iloc[-30:]
print(train.shape, teste.shape)
# Out:
# (628, 4)
# (598, 4) (30, 4)

# %%
model=ARIMA(dados_filtrados['temperatura'],order=(0,1,0))
model=model.fit()
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                              ARIMA Model Results
# ...
# Dep. Variable:          D.temperatura   No. Observations:                  627
# Model:                 ARIMA(0, 1, 0)   Log Likelihood                 209.921
# Method:                           css   S.D. of innovations              0.173
# Date:                Wed, 25 Nov 2020   AIC                           -415.842
# Time:                        19:48:22   BIC                           -406.960
# Sample:                             1   HQIC                          -412.391
#
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0053      0.007      0.761      0.447      -0.008       0.019
# ...
# """

# %%
start=len(dados_filtrados)
end=len(dados_filtrados)+len(teste)-1
pred=model.predict(start=start,end=end,typ='levels')
print(pred)
# Out:
# 627    33.405263
# 628    33.410526
# 629    33.415789
# 630    33.421053
# 631    33.426316
# 632    33.431579
# 633    33.436842
# 634    33.442105
# 635    33.447368
# 636    33.452632
# 637    33.457895
# 638    33.463158
# 639    33.468421
# 640    33.473684
# 641    33.478947
# 642    33.484211
# 643    33.489474
# 644    33.494737
# 645    33.500000
# 646    33.505263
# 647    33.510526
# 648    33.515789
# 649    33.521053
# 650    33.526316
# 651    33.531579
# 652    33.536842
# 653    33.542105
# 654    33.547368
# 655    33.552632
# 656    33.557895
# dtype: float64

# %%
pred.plot(legend=True)
teste['temperatura'].plot(legend=True)

# %%
teste['temperatura'].mean()
# Out:
# 33.42333333333332

# %%
from sklearn.metrics import mean_squared_error
from math import sqrt
maquina=sqrt(mean_squared_error(pred,teste['temperatura']))
print(maquina)
# Out:
# 0.11940140019061898

# %%
model2=ARIMA(dados_filtrados['temperatura'],order=(0,1,0))
model2=model2.fit()
tabela1.tail()
# Out:
#         id  temperatura  umidade             horario
# 3847  4309         20.5     90.0 2020-11-19 22:33:22
# 3848  4310         20.3     90.0 2020-11-19 22:33:31
# 3849  4311         20.2     90.0 2020-11-19 22:33:40
# 3850  4312         20.2     90.0 2020-11-19 22:33:48
# 3851  4313         20.2     90.0 2020-11-19 22:33:57

# %%
index_future_dates=tabela1.date_range(start='2020-11-19',end='2020-12-19')

print(index_future_dates)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-134-f45233ded77d> in <module>()
# ----> 1 index_future_dates=tabela1.date_range(start='2020-11-19', end='2020-12-19')
#       2
#       3 print(index_future_dates)
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/generic.py in __getattr__(self, name)
#    5137             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5138                 return self[name]
# -> 5139             return object.__getattribute__(self, name)
#    5140
#    5141     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'date_range'

# %%
pred=model2.predict(start=len(dados_filtrados),end=len(dados_filtrados)+30,typ='levels').rename('ARIMA PREDICOES')
print(pred)
# Out:
# 627    33.405263
# 628    33.410526
# 629    33.415789
# 630    33.421053
# 631    33.426316
# 632    33.431579
# 633    33.436842
# 634    33.442105
# 635    33.447368
# 636    33.452632
# 637    33.457895
# 638    33.463158
# 639    33.468421
# 640    33.473684
# 641    33.478947
# 642    33.484211
# 643    33.489474
# 644    33.494737
# 645    33.500000
# 646    33.505263
# 647    33.510526
# 648    33.515789
# 649    33.521053
# 650    33.526316
# 651    33.531579
# 652    33.536842
# 653    33.542105
# 654    33.547368
# 655    33.552632
# 656    33.557895
# 657    33.563158
# Name: ARIMA PREDICOES, dtype: float64

# %%
pred.index=index_future_dates
print(pred)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-115-26f4f93df792> in <module>()
# ----> 1 pred.index=index_future_dates
#       2 print(pred)
#
# NameError: name 'index_future_dates' is not defined

# %%
pred.plot(figsize=(12,5),legend=True)
